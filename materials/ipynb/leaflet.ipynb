# %%
import pandas as pd

arrest_tab = pd.read_csv("http://www.hcbravo.org/IntroDataSci/misc/BPD_Arrests.csv")

dat = arrest_tab[arrest_tab['Location 1'].notna()].copy()
dat['lat'] = dat['Location 1'].str.extract("\(([0-9\.\-]*).*\)", expand=False)
dat['lng'] = dat['Location 1'].str.extract("\(.*,(.*)\)", expand=False)
dat = dat.sample(n=2000)
dat
# Out:
#            arrest  age race sex  arrestDate arrestTime  \
# 89067  12544355.0   34    B   M  09/02/2012   00:12:00
# 54153  12401217.0   22    B   M  01/10/2012   18:00:00
# 44780  11359104.0   48    B   M  11/01/2011   10:05:00
# 3926   11144189.0   33    B   M  02/02/2011   18:30:00
# 41648  11343704.0   25    B   M  10/11/2011   10:45:00
# ...           ...  ...  ...  ..         ...        ...
# 54137  12401192.0   42    B   F  01/10/2012   17:00:00
# 50328  11384856.0   62    B   M  12/11/2011   01:55:00
# 25396  11251781.0   40    W   M  06/24/2011   00:45:00
# 90622  12550714.0   28    B   M  09/12/2012   14:00:00
# 81703  12514374.0   43    B   M  07/17/2012   01:30:00
#
#                 arrestLocation          incidentOffense  \
# 89067      2200 Druid Hill Ave          54-Armed Person
# 54153  5200 Linden Heights Ave             87-Narcotics
# 44780         5300 Cuthbert St             87-Narcotics
# 3926            900 Fulton Ave        4E-Common Assault
# 41648          1000 N Mount St                 79-Other
# ...                        ...                      ...
# 54137           200 Herring Ct             87-Narcotics
# 50328           300 N Eutaw St     4F-Assault By Threat
# 25396           800 Jeffrey St  87O-Narcotics (Outside)
# 90622         0 S Highland Ave             87-Narcotics
# 81703             700 Brune St      23-Unauthorized Use
#
#              incidentLocation  charge  \
# 89067      2300 Druid Hill Av  1 1609
# 54153  5200 Linden Heights Av  4 3550
# 44780     3700 W Belvedere Av  1 0573
# 3926          900 N Fulton Av  1 1415
# 41648     300 N Carrollton Av  1 1106
# ...                       ...     ...
# 54137          200 Herring Ct  4 3550
# 50328            400 Manse Ct  1 5200
# 25396        800 E Jeffrey St  1 0573
# 90622         0 S Highland Av  4 3550
# 81703            700 Brune St  1 0600
#
#                                        chargeDescription      district   post  \
# 89067                                                NaN       CENTRAL  135.0
# 54153    Cds:Possess-Not Marihuana || Poss W/Int Cocaine  NORTHWESTERN  634.0
# 44780     Cds: Possession-Marihuana || Poss Of Marijuana  NORTHWESTERN  634.0
# 3926                         Asslt-Sec Degree || Assault       WESTERN  724.0
# 41648  Reg Firearm:Illegal Possession || Handgun Viol...       WESTERN  715.0
# ...                                                  ...           ...    ...
# 54137          Cds:Possess-Not Marihuana || Poss Cocaine  SOUTHEASTERN  212.0
# 50328  Deadly Weapon-Int/Injure || Poss Of A Deadly W...       CENTRAL  121.0
# 25396         Cds: Possession-Marihuana || Cds Violation      SOUTHERN  913.0
# 90622                   Cds:Possess-Not Marihuana || Cds  SOUTHEASTERN  224.0
# 81703   Resist/Interfere With Arrest || Unauthorized Use       CENTRAL  122.0
#
#               neighborhood                       Location 1            lat  \
# 89067        Druid Heights  (39.3091538569, -76.6374713057)  39.3091538569
# 54153             Woodmere  (39.3443765156, -76.6839891680)  39.3443765156
# 44780            Arlington  (39.3481389892, -76.6828753726)  39.3481389892
# 3926   Sandtown-Winchester  (39.2990302202, -76.6458982023)  39.2990302202
# 41648  Sandtown-Winchester  (39.3003489285, -76.6444829033)  39.3003489285
# ...                    ...                              ...            ...
# 54137        Perkins Homes  (39.2889367422, -76.5951382012)  39.2889367422
# 50328             Downtown  (39.2929794458, -76.6211885580)  39.2929794458
# 25396             Brooklyn  (39.2323872193, -76.6005198340)  39.2323872193
# 90622  Baltimore Highlands  (39.2921348214, -76.5693522951)  39.2921348214
# 81703    Heritage Crossing  (39.2964664051, -76.6308241919)  39.2964664051
#
#                    lng
# 89067   -76.6374713057
# 54153   -76.6839891680
# 44780   -76.6828753726
# 3926    -76.6458982023
# 41648   -76.6444829033
# ...                ...
# 54137   -76.5951382012
# 50328   -76.6211885580
# 25396   -76.6005198340
# 90622   -76.5693522951
# 81703   -76.6308241919
#
# [2000 rows x 17 columns]

# %%
from ipyleaflet import *

# %%
m = Map(center=(39.29, -76.61), zoom=11)
m
# Out:
# Map(center=[39.29, -76.61], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_…
